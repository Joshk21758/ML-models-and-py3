# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier

#Pandas read file
app_det = pd.read_csv('Applicant-details.csv')
app_det
# Out:
#        Applicant_ID  Annual_Income  Applicant_Age  Work_Experience  \
# 0             75722        9657655             76                0
# 1             80185        9259353             37               18
# 2             19865        1509721             66                8
# 3             76700        5867312             43                1
# 4             92992        7223191             44                9
# ...             ...            ...            ...              ...
# 99995          6266         156398             69               10
# 99996         54887        1900932             69               11
# 99997         76821        6395936             66               11
# 99998           861        4505937             52                6
# 99999         15796        4186842             58                9
#
#       Marital_Status House_Ownership Vehicle_Ownership(car)  \
# 0             single          rented                     no
# ...

# %%
X = app_det.drop(columns=['Marital_Status', 'House_Ownership', 'Vehicle_Ownership(car)', 'Occupation', 'Residence_City', 'Residence_State'], axis=1)
X
# Out:
#        Applicant_ID  Annual_Income  Applicant_Age  Work_Experience  \
# 0             75722        9657655             76                0
# 1             80185        9259353             37               18
# 2             19865        1509721             66                8
# 3             76700        5867312             43                1
# 4             92992        7223191             44                9
# ...             ...            ...            ...              ...
# 99995          6266         156398             69               10
# 99996         54887        1900932             69               11
# 99997         76821        6395936             66               11
# 99998           861        4505937             52                6
# 99999         15796        4186842             58                9
#
#        Years_in_Current_Employment  Years_in_Current_Residence  \
# 0                                0                          12
# ...

# %%
y = app_det.drop(columns=['Applicant_ID', 'Annual_Income', 'Applicant_Age', 'Work_Experience', 'Years_in_Current_Employment', 'Years_in_Current_Residence', 'Loan_Default_Risk'], axis=1)
y
# Out:
#       Marital_Status House_Ownership Vehicle_Ownership(car)  \
# 0             single          rented                     no
# 1             single          rented                     no
# 2             single          rented                     no
# 3             single           owned                     no
# 4             single          rented                     no
# ...              ...             ...                    ...
# 99995         single          rented                    yes
# 99996         single          rented                     no
# 99997         single           owned                     no
# 99998         single          rented                     no
# 99999         single          rented                    yes
#
#                    Occupation Residence_City Residence_State
# 0                Psychologist      Jalandhar          Punjab
# 1          Petroleum_Engineer          Bally     West_Bengal
# ...

# %%
#Build, fit & predict model
model = DecisionTreeClassifier()
model.fit(X, y)

predictions = model.predict([ [19865, 1509721, 66, 8, 4, 12, 0] ])
predictions
# Out:
# C:\Users\Kunda\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([['single', 'rented', 'no', 'Drafter', 'Indore', 'Madhya_Pradesh']],
#       dtype=object)
